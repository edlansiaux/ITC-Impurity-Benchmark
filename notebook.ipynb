# %%
# !pip install ucimlrepo
# %run data/data_loader.py

# %%
# %run run_all_benchmarks.py
# Out:
# ...
# BENCHMARK COMPLET DES MÉTRIQUES D'IMPURETÉ
# ...
# ✓ Dossier créé: results/raw_results
# ✓ Dossier créé: results/tables
# ✓ Dossier créé: results/figures
# ✓ Dossier créé: data/datasets
#
# Début du benchmark: 2025-11-01 08:16:39
#
# ...
# 1. BENCHMARK DES MÉTRIQUES INDIVIDUELLES
# ...
# Datasets sklearn chargés avec succès!
# Création des datasets synthétiques...
# ✓ Datasets synthétiques créés avec succès!
#
# Benchmark sur le dataset: iris
# Taille: (150, 4), Classes: 3
# ...
# Runs iris: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:08<00:00,  1.60s/it]
# Benchmark sur le dataset: wine
# Taille: (178, 13), Classes: 3
# ...

# %%
# %run fix.py
# %run run_all.py
